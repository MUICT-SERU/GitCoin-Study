# %% [markdown]
# This notebook aims to address the reviewer's comment on the study of crypto coin real values.

# %%
import numpy as np
import pandas as pd

# %%
#the file that contains all issues and all fields
allBounty = pd.read_csv("dataset/gitcoin_dataset_5.csv")

#fill-in 'numerical values' with their median
allBounty['value_in_eth'].fillna(float(allBounty['value_in_eth'].median()), inplace = True)
allBounty['value_in_usdt_now'].fillna(float(allBounty['value_in_usdt_now'].median()), inplace = True)
allBounty['value_in_usdt'].fillna(float(allBounty['value_in_usdt'].median()), inplace = True)
allBounty['token_value_in_usdt'].fillna(float(allBounty['token_value_in_usdt'].median()), inplace = True)

#fill-in 'categorical values' with "NA" (except for github_issue_number)
# allBounty['title'].fillna("NA", inplace = True)
# allBounty['funder_last_messaged_on'].fillna("NA", inplace = True)
# allBounty['is_reserved'].fillna("NA", inplace = True)
# allBounty['canceled_bounty_reason'].fillna("NA", inplace = True)
# allBounty['reserved_for_user_handle'].fillna("NA", inplace = True)
# allBounty['attached_job_description'].fillna("NA", inplace = True)
# allBounty['canceled_on'].fillna("NA", inplace = True)
# allBounty['funding_organisation'].fillna("NA", inplace = True)
# allBounty['featuring_date'].fillna("NA", inplace = True)
# allBounty['fulfillment_accepted_on'].fillna("NA", inplace = True)
# allBounty['fulfillment_submitted_on'].fillna("NA", inplace = True)
# allBounty['fulfillment_started_on'].fillna("NA", inplace = True)
# allBounty['keywords'].fillna("NA", inplace = True)
# allBounty['bounty_owner_name'].fillna("NA", inplace = True)
# allBounty['github_issue_state'].fillna("NA", inplace = True)
# allBounty['bounty_owner_github_username'].fillna("NA", inplace = True)
# allBounty['bounty_owner_email'].fillna("NA", inplace = True)
# allBounty['github_issue_number'].fillna(0, inplace = True)
# allBounty['github_repo_name'].fillna("NA", inplace = True)
# allBounty['org_name'].fillna("NA", inplace = True)
# allBounty['github_org_name'].fillna("NA", inplace = True)

# allBounty.loc[allBounty['bounty_type'] == "0", 'bounty_type'] = "Other"
# allBounty.loc[allBounty['bounty_type'] == "Andere", 'bounty_type'] = "Other"
# allBounty.loc[allBounty['bounty_type'] == "Funkcja", 'bounty_type'] = "Other"
# allBounty.loc[allBounty['bounty_type'] == "æ¹å", 'bounty_type'] = "Other"
# allBounty['bounty_type'].fillna("NA", inplace = True)

# allBounty.loc[allBounty['experience_level'] == "0", 'experience_level'] = "Other"
# allBounty.loc[allBounty['experience_level'] == "Mittlere", 'experience_level'] = "Intermediate"
# allBounty.loc[allBounty['experience_level'] == "åå¿è", 'experience_level'] = "Other"
# allBounty.loc[allBounty['experience_level'] == "Pośredni", 'experience_level'] = "Intermediate"
# allBounty['experience_level'].fillna("NA", inplace = True)

# allBounty.loc[allBounty['project_length'] == "0", 'project_length'] = "Unknown"
# allBounty.loc[allBounty['project_length'] == "Tage", 'project_length'] = "Days"
# allBounty.loc[allBounty['project_length'] == "Miesięcy", 'project_length'] = "Months"
# allBounty['project_length'].fillna("NA", inplace = True)


# outer_merged['increased_bounty_times'].fillna(0, inplace = True)
# outer_merged['changed_bounty_value'].fillna(0, inplace = True)

# outer_merged['firstAct_activity_type'].fillna("NA", inplace = True)
# outer_merged['lastAct_activity_type'].fillna("NA", inplace = True)

# outer_merged['duration_create_to_done'].fillna(0, inplace = True)
# outer_merged['duration_create_to_firstAct'].fillna(0, inplace = True)
# outer_merged['duration_create_to_killed'].fillna(0, inplace = True)
# outer_merged['duration_create_to_lastAct'].fillna(0, inplace = True)
# outer_merged['duration_create_to_new_bounty'].fillna(0, inplace = True)
# outer_merged['duration_create_to_start'].fillna(0, inplace = True)
# outer_merged['duration_create_to_stop'].fillna(0, inplace = True)
# outer_merged['duration_create_to_submitted'].fillna(0, inplace = True)
# outer_merged['duration_create_to_worker_applied'].fillna(0, inplace = True)
# outer_merged['number_of_user_in_activities'].fillna(0, inplace = True)

# #change cathegory to number

# #experience_level
# outer_merged['experience_level_code'] = outer_merged['experience_level']
# find_replace = {"experience_level_code" : {"NA": 0, "Other": 0, "Beginner": 1, "Intermediate": 2, "Advanced": 3}}
# outer_merged.replace(find_replace, inplace=True)

# #project_length
# outer_merged['project_length_code'] = outer_merged['project_length']
# find_replace = {"project_length_code" : {"NA": 0, "Unknown": 0, "Hours": 1, "Days": 24, "Weeks": 168, "Months": 720}} #in hours
# outer_merged.replace(find_replace, inplace=True)

# #normalization
# #https://towardsdatascience.com/everything-you-need-to-know-about-min-max-normalization-in-python-b79592732b79
# from sklearn.preprocessing import MinMaxScaler

# min_max_scaler = MinMaxScaler() 
# column_names_to_normalize = ['changed_bounty_value','github_comments','increased_bounty_times','description_length','duration_create_to_expire','number_of_activities','number_of_fulfillments','number_of_interests','token_value_in_usdt','value_in_eth','value_in_token','value_in_usdt','value_in_usdt_now','duration_create_to_done','duration_create_to_firstAct','duration_create_to_killed','duration_create_to_lastAct','duration_create_to_new_bounty','duration_create_to_start','duration_create_to_stop','duration_create_to_submitted','duration_create_to_worker_applied','number_of_user_in_activities']
# x = outer_merged[column_names_to_normalize].values
# x_scaled = min_max_scaler.fit_transform(x)
# outer_merged_temp = pd.DataFrame(x_scaled, columns=column_names_to_normalize, index = outer_merged.index)
# outer_merged[column_names_to_normalize] = outer_merged_temp

# pd.set_option('display.max_columns', None)
# outer_merged_temp.describe()
# outer_merged_temp.shape
# outer_merged.describe()
# outer_merged.shape

# #all features used in Table 2 Feature Description
# columns_temp = ['pk','is_success','duration_create_to_expire','value_in_eth','value_in_token','value_in_usdt','value_in_usdt_now',
#                 'project_length_code','experience_level_code','project_type',
#                 'github_comments','number_of_activities','number_of_fulfillments','number_of_interests',
#                 'description_length','duration_create_to_done','duration_create_to_firstAct','duration_create_to_lastAct',
#                 'duration_create_to_submitted','duration_create_to_killed','duration_create_to_new_bounty',
#                 'duration_create_to_start','duration_create_to_stop','duration_create_to_worker_applied',
#                 'number_of_user_in_activities','changed_bounty_value','increased_bounty_times','bounty_type','token_name',
#                 'firstAct_activity_type','lastAct_activity_type']

# outer_merged_temp = outer_merged[columns_temp]
# outer_merged = outer_merged_temp

# feature_to_trans_set1 = ['bounty_type','token_name','project_type','firstAct_activity_type','lastAct_activity_type']

# new_raw_data_set1 = pd.get_dummies(outer_merged, columns = feature_to_trans_set1)

# %%
allBounty.columns.tolist()
# Out:
# ['admin_override_suspend_auto_approval',
#  'attached_job_description',
#  'avatar_url',
#  'bounty_categories',
#  'bounty_owner_address',
#  'bounty_owner_email',
#  'bounty_owner_github_username',
#  'bounty_owner_name',
#  'bounty_type',
#  'can_remarket',
#  'can_submit_after_expiration_date',
#  'canceled_bounty_reason',
#  'canceled_on',
#  'created_on',
#  'current_bounty',
#  'description_length',
#  'duration_create_to_expire',
#  'experience_level',
#  'expires_date',
#  'expires_date_ymd',
#  'featuring_date',
#  'fulfillment_accepted_on',
#  'fulfillment_started_on',
#  'fulfillment_submitted_on',
#  'funder_last_messaged_on',
#  'funding_organisation',
#  'github_comments',
#  'github_issue_number',
#  'github_issue_state',
#  'github_org_name',
#  'github_repo_name',
#  'github_url',
#  'idx_status',
#  'is_featured',
#  'is_issue_closed',
#  'is_open',
#  'is_paid',
#  'is_reserved',
#  'is_success',
#  'keywords',
#  'modified_on',
#  'needs_review',
#  'network',
# ...

# %%
# 'web3_created',
# 'token_name',
# 'token_value_in_usdt',
# 'token_value_time_peg',
# 'value_in_eth',
# 'value_in_token',
# 'value_in_usdt',
# 'value_in_usdt_now'

columns_to_summary = ['web3_created', 'token_name', 'token_value_in_usdt', 'token_value_time_peg', 'value_in_eth', 'value_in_token', 'value_in_usdt', 'value_in_usdt_now']
summary = allBounty[columns_to_summary].describe()
print(summary)
# Out:
#        token_value_in_usdt  value_in_eth  value_in_token  value_in_usdt  \
# count          4584.000000   4584.000000    4.584000e+03   4.584000e+03
# mean            272.231459      4.125349    6.465640e+21   2.509994e+03
# std             876.648542    146.254521    1.875734e+23   8.622930e+04
# min               0.000000      0.000000    0.000000e+00   0.000000e+00
# 25%               1.000000      0.070000    1.500000e+17   5.000000e+01
# 50%             122.000000      0.180000    1.400000e+18   1.178500e+02
# 75%             317.860000      0.500000    1.200000e+20   3.273125e+02
# max           35564.840000   7000.000000    1.101637e+25   4.121180e+06
#
#        value_in_usdt_now
# count       4.584000e+03
# mean        5.922157e+03
# std         1.998284e+05
# min         0.000000e+00
# 25%         9.948000e+01
# 50%         2.500000e+02
# 75%         7.581250e+02
# max         9.559033e+06

# %%
import matplotlib.pyplot as plt

token_name_counts = allBounty['token_name'].value_counts()

plt.figure(figsize=(10, 6))
token_name_counts.plot(kind='bar')
plt.xlabel('Token Name')
plt.ylabel('Count')
plt.title('Token Name Distribution')
plt.show()

# %%
print(allBounty['token_value_time_peg'])
# Out:
# 0       2018-08-15T11:17:26Z
# 1       2018-08-15T14:56:03Z
# 2       2018-08-15T16:28:39Z
# 3       2018-08-15T17:25:42Z
# 4       2018-08-15T18:21:29Z
#                 ...
# 4579    2018-08-13T22:57:29Z
# 4580    2018-08-14T18:43:07Z
# 4581    2018-08-14T22:19:35Z
# 4582    2018-08-14T22:56:03Z
# 4583    2018-08-15T11:09:25Z
# Name: token_value_time_peg, Length: 4584, dtype: object

# %%
print(allBounty['token_value_in_usdt'])
# Out:
# 0       288.64
# 1         1.00
# 2         1.00
# 3         1.00
# 4       288.64
#          ...
# 4579      1.00
# 4580      1.00
# 4581    263.16
# 4582      1.00
# 4583    288.64
# Name: token_value_in_usdt, Length: 4584, dtype: float64

# %%
filtered_values = allBounty.loc[allBounty['token_name'].isin(['DAI', 'ETH']), 'token_value_in_usdt']
print(filtered_values)
# Out:
# 0       288.64
# 1         1.00
# 2         1.00
# 3         1.00
# 4       288.64
#          ...
# 4579      1.00
# 4580      1.00
# 4581    263.16
# 4582      1.00
# 4583    288.64
# Name: token_value_in_usdt, Length: 3624, dtype: float64

# %%
filtered_values.describe()
# Out:
# count    3624.000000
# mean      314.041120
# std       394.765091
# min         0.000000
# 25%         1.000000
# 50%       173.580000
# 75%       452.760000
# max      1398.920000
# Name: token_value_in_usdt, dtype: float64

# %%
import matplotlib.pyplot as plt

filtered_data = allBounty.loc[allBounty['token_name'].isin(['DAI', 'ETH']), ['token_value_time_peg', 'token_value_in_usdt']]
filtered_data = filtered_data.sort_values('token_value_time_peg')  # Sort the values by time for a line plot

plt.figure(figsize=(10, 6))
plt.plot(filtered_data['token_value_time_peg'], filtered_data['token_value_in_usdt'])
plt.xlabel('Token Value Time Peg')
plt.ylabel('Token Value in USDT')
plt.title('Token Value in USDT over Time')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

filtered_data = allBounty.loc[allBounty['token_name'].isin(['ETH']), ['token_value_time_peg', 'token_value_in_usdt']]
filtered_data = filtered_data.sort_values('token_value_time_peg')  # Sort the values by time for a line plot

plt.figure(figsize=(10, 6))
plt.plot(filtered_data['token_value_time_peg'], filtered_data['token_value_in_usdt'])
plt.xlabel('Token Value Time Peg')
plt.ylabel('Token Value in USDT')
plt.title('Token Value in USDT over Time')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

filtered_data = allBounty.loc[allBounty['token_name'].isin(['DAI']), ['token_value_time_peg', 'token_value_in_usdt']]
filtered_data = filtered_data.sort_values('token_value_time_peg')  # Sort the values by time for a line plot

plt.figure(figsize=(10, 6))
plt.plot(filtered_data['token_value_time_peg'], filtered_data['token_value_in_usdt'])
plt.xlabel('Token Value Time Peg')
plt.ylabel('Token Value in USDT')
plt.title('Token Value in USDT over Time')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from datetime import datetime

filtered_data = allBounty.loc[allBounty['token_name'].isin(['ETH']), ['token_value_time_peg', 'token_value_in_usdt']]
filtered_data['token_value_time_peg'] = pd.to_datetime(filtered_data['token_value_time_peg'])  # Convert to datetime format
filtered_data = filtered_data.sort_values('token_value_time_peg')  # Sort the values by time for a line plot

plt.figure(figsize=(10, 6))
plt.plot(filtered_data['token_value_time_peg'], filtered_data['token_value_in_usdt'])
plt.xlabel('Month and Year')
plt.ylabel('Token Value in USDT')
plt.title('Token Value in USDT over Time')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

filtered_data = allBounty.loc[allBounty['token_name'].isin(['ETH']), ['token_value_time_peg', 'token_value_in_usdt', 'is_success']]
filtered_data['token_value_time_peg'] = pd.to_datetime(filtered_data['token_value_time_peg'])  # Convert to datetime format
filtered_data = filtered_data.set_index('token_value_time_peg')  # Set the index to the time column


filtered_data2 = allBounty.loc[allBounty['token_name'].isin(['ETH']), ['token_value_time_peg', 'token_value_in_usdt']]
filtered_data2['token_value_time_peg'] = pd.to_datetime(filtered_data2['token_value_time_peg'])  # Convert to datetime format
filtered_data2 = filtered_data2.sort_values('token_value_time_peg') 

plt.figure(figsize=(10, 6))

# Plot token_value_in_usdt
plt.plot(filtered_data2['token_value_time_peg'], filtered_data2['token_value_in_usdt'])
plt.xlabel('Month and Year')
plt.ylabel('Token Value in USDT')

# Calculate count of 'True' values grouped by month
success_count_monthly = filtered_data.resample('M')['is_success'].apply(lambda x: (x == True).sum())

# Create secondary y-axis for success count
ax2 = plt.twinx()

# Plot success count as a bar chart
ax2.bar(success_count_monthly.index, success_count_monthly.values, alpha=0.5, color='green', label='Success Count')
ax2.set_ylabel('No. of success issues')

# plt.title('Token Value in USDT and Success Count over Time (Grouped by Month)')
plt.xticks(rotation=45, ha='right', fontsize=12)  # Rotate x-axis labels for better readability
plt.yticks(fontsize=12)


# Display legends for both plots
lines, labels = plt.gca().get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
# plt.legend(lines + lines2, labels + labels2, loc='upper left')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from datetime import datetime

filtered_data = allBounty.loc[allBounty['token_name'].isin(['ETH']), ['token_value_time_peg', 'token_value_in_usdt', 'is_success']]
filtered_data['token_value_time_peg'] = pd.to_datetime(filtered_data['token_value_time_peg'])  # Convert to datetime format
filtered_data = filtered_data.sort_values('token_value_time_peg')  # Sort the values by time for a line plot

plt.figure(figsize=(10, 6))

# Plot token_value_in_usdt
plt.plot(filtered_data['token_value_time_peg'], filtered_data['token_value_in_usdt'], label='Token Value in USDT')
plt.xlabel('Month and Year')
plt.ylabel('Token Value in USDT')

# Calculate count of 'True' values grouped by timeline (month and year)
timeline_counts = filtered_data.loc[filtered_data['is_success']].groupby(filtered_data['token_value_time_peg'].dt.to_period('M')).size()

# Plot line for count of 'True' values
plt.plot(timeline_counts.index.to_timestamp(), timeline_counts.values, label='Count of True in is_success')

plt.title('Token Value in USDT and Count of True in is_success over Time')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [15], line 16
#      13 plt.ylabel('Token Value in USDT')
#      15 # Calculate count of 'True' values grouped by timeline (month and year)
# ---> 16 timeline_counts = filtered_data.loc[filtered_data['is_success']].groupby(filtered_data['token_value_time_peg'].dt.to_period('M')).size()
#      18 # Plot line for count of 'True' values
#      19 plt.plot(timeline_counts.index.to_timestamp(), timeline_counts.values, label='Count of True in is_success')
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/indexing.py:895, in _LocationIndexer.__getitem__(self, key)
#     892 axis = self.axis or 0
#     894 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

filtered_data = allBounty.loc[allBounty['token_name'] == 'ETH', ['token_value_time_peg', 'token_value_in_usdt', 'is_success']]
filtered_data['token_value_time_peg'] = pd.to_datetime(filtered_data['token_value_time_peg'])  # Convert to datetime format
filtered_data = filtered_data.sort_values('token_value_time_peg')  # Sort the values by time for a line plot

plt.figure(figsize=(10, 6))

# Plot token_value_in_usdt
plt.plot(filtered_data['token_value_time_peg'], filtered_data['token_value_in_usdt'], label='Token Value in USDT')
plt.xlabel('Month and Year')
plt.ylabel('Token Value in USDT')

# Calculate count of 'True' values grouped by month and year
timeline_counts = filtered_data.loc[filtered_data['is_success']].groupby(filtered_data['token_value_time_peg'].dt.to_period('M')).size()

# Overlay bar chart for count of 'True' values
plt.bar(timeline_counts.index.to_timestamp(), timeline_counts.values, alpha=0.5, color='green', label='Count of True in is_success')

plt.title('Token Value in USDT and Count of True in is_success over Time')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

filtered_data = allBounty.loc[allBounty['token_name'].isin(['ETH']), ['token_value_time_peg', 'token_value_in_usdt','is_success']]
filtered_data['token_value_time_peg'] = pd.to_datetime(filtered_data['token_value_time_peg'])  # Convert to datetime format
filtered_data = filtered_data.sort_values('token_value_time_peg')  # Sort the values by time for a line plot

plt.figure(figsize=(10, 6))
plt.plot(filtered_data['token_value_time_peg'], filtered_data['token_value_in_usdt'])
plt.xlabel('Month and Year')
plt.ylabel('Token Value in USDT')
plt.title('Token Value in USDT over Time')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.grid(True)

# Calculate count of 'True' values grouped by month and year
timeline_counts = filtered_data.loc[filtered_data['is_success']].groupby(filtered_data['token_value_time_peg'].dt.to_period('M')).size()

# Add bar chart for count of 'True' values
plt.twinx()
plt.bar(timeline_counts.index.to_timestamp(), timeline_counts.values, alpha=0.5, color='green', label='Count of True in is_success')
plt.ylabel('Count of True in is_success')

plt.legend(loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

filtered_data = allBounty[['token_value_time_peg', 'token_value_in_usdt']]
filtered_data['token_value_time_peg'] = pd.to_datetime(filtered_data['token_value_time_peg'])  # Convert to datetime format
filtered_data = filtered_data.sort_values('token_value_time_peg')  # Sort the values by time for a line plot

plt.figure(figsize=(10, 6))

# Calculate the average token_value_in_usdt on timeline
average_values = filtered_data.groupby(filtered_data['token_value_time_peg'].dt.to_period('M'))['token_value_in_usdt'].mean()

# Plot the line graph of the average token_value_in_usdt
plt.plot(average_values.index.to_timestamp(), average_values.values)
plt.xlabel('Month and Year', fontsize=12)
plt.ylabel('Average Token Value in USD', fontsize=12)
# plt.title('Average Token Value in USD over Time')
plt.xticks(rotation=45, ha='right', fontsize=12)  # Rotate x-axis labels for better readability
plt.yticks(fontsize=12)  # Increase font size of y-axis tick labels
plt.grid(True)
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c7dbb46d-be11-4d98-a8ae-f659e78e24c4' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
