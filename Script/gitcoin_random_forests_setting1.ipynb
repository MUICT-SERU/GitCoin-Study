# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from sklearn.metrics import recall_score
from imblearn.over_sampling import SMOTE

# %%
#the file that contains all issues and all fields
allBounty = pd.read_csv("gitcoin_dataset_5.csv")

#the file that contains fields from 'activities' array e.g. activity_type, duration_create_to_done
activity_coll = pd.read_csv("activities_collection_3.csv")

#the file that contains '# of times bounty increased' from 'activities' array
bounty_changed = pd.read_csv("changedBounty2.csv")

# %%
#Cleansing data

activity_coll.drop('duration_worker_applied_to_worker_approved',axis='columns', inplace=True)

#fill-in 'numerical values' with their median
allBounty['value_in_eth'].fillna(float(allBounty['value_in_eth'].median()), inplace = True)
allBounty['value_in_usdt_now'].fillna(float(allBounty['value_in_usdt_now'].median()), inplace = True)
allBounty['value_in_usdt'].fillna(float(allBounty['value_in_usdt'].median()), inplace = True)
allBounty['token_value_in_usdt'].fillna(float(allBounty['token_value_in_usdt'].median()), inplace = True)

#fill-in 'categorical values' with "NA" (except for github_issue_number)
allBounty['title'].fillna("NA", inplace = True)
allBounty['funder_last_messaged_on'].fillna("NA", inplace = True)
allBounty['is_reserved'].fillna("NA", inplace = True)
allBounty['canceled_bounty_reason'].fillna("NA", inplace = True) 
allBounty['reserved_for_user_handle'].fillna("NA", inplace = True)
allBounty['attached_job_description'].fillna("NA", inplace = True)
allBounty['canceled_on'].fillna("NA", inplace = True)
allBounty['funding_organisation'].fillna("NA", inplace = True) 
allBounty['featuring_date'].fillna("NA", inplace = True)
allBounty['fulfillment_accepted_on'].fillna("NA", inplace = True)
allBounty['fulfillment_submitted_on'].fillna("NA", inplace = True)
allBounty['fulfillment_started_on'].fillna("NA", inplace = True)
allBounty['keywords'].fillna("NA", inplace = True)
allBounty['bounty_owner_name'].fillna("NA", inplace = True)
allBounty['github_issue_state'].fillna("NA", inplace = True)
allBounty['bounty_owner_github_username'].fillna("NA", inplace = True)
allBounty['bounty_owner_email'].fillna("NA", inplace = True)
allBounty['github_repo_name'].fillna("NA", inplace = True)
allBounty['org_name'].fillna("NA", inplace = True)
allBounty['github_org_name'].fillna("NA", inplace = True)
allBounty['github_issue_number'].fillna(0, inplace = True)

allBounty.loc[allBounty['bounty_type'] == "0", 'bounty_type'] = "Other"
allBounty.loc[allBounty['bounty_type'] == "Andere", 'bounty_type'] = "Other"
allBounty.loc[allBounty['bounty_type'] == "Funkcja", 'bounty_type'] = "Other"
allBounty.loc[allBounty['bounty_type'] == "æ¹å", 'bounty_type'] = "Other"
allBounty['bounty_type'].fillna("NA", inplace = True)

allBounty.loc[allBounty['experience_level'] == "0", 'experience_level'] = "Other"
allBounty.loc[allBounty['experience_level'] == "Mittlere", 'experience_level'] = "Intermediate"
allBounty.loc[allBounty['experience_level'] == "åå¿è", 'experience_level'] = "Other"
allBounty.loc[allBounty['experience_level'] == "Pośredni", 'experience_level'] = "Intermediate"
allBounty['experience_level'].fillna("NA", inplace = True)

allBounty.loc[allBounty['project_length'] == "0", 'project_length'] = "Unknown"
allBounty.loc[allBounty['project_length'] == "Tage", 'project_length'] = "Days"
allBounty.loc[allBounty['project_length'] == "Miesięcy", 'project_length'] = "Months"
allBounty['project_length'].fillna("NA", inplace = True)

# %%
#merge two dataframe together

outer_merged = pd.merge(allBounty, activity_coll, how="outer", on=["pk"])
outer_merged = pd.merge(outer_merged, bounty_changed, how="outer", on=["pk"])

outer_merged['increased_bounty_times'].fillna(0, inplace = True)
outer_merged['changed_bounty_value'].fillna(0, inplace = True)

outer_merged['firstAct_activity_type'].fillna("NA", inplace = True)
outer_merged['lastAct_activity_type'].fillna("NA", inplace = True)

outer_merged['duration_create_to_done'].fillna(0, inplace = True)
outer_merged['duration_create_to_firstAct'].fillna(0, inplace = True)
outer_merged['duration_create_to_killed'].fillna(0, inplace = True)
outer_merged['duration_create_to_lastAct'].fillna(0, inplace = True)
outer_merged['duration_create_to_new_bounty'].fillna(0, inplace = True)
outer_merged['duration_create_to_start'].fillna(0, inplace = True)
outer_merged['duration_create_to_stop'].fillna(0, inplace = True)
outer_merged['duration_create_to_submitted'].fillna(0, inplace = True)
outer_merged['duration_create_to_worker_applied'].fillna(0, inplace = True)
outer_merged['number_of_user_in_activities'].fillna(0, inplace = True)

# %%
#change cathegory to number

#experience_level
outer_merged['experience_level_code'] = outer_merged['experience_level']
find_replace = {"experience_level_code" : {"NA": 0, "Other": 0, "Beginner": 1, "Intermediate": 2, "Advanced": 3}}
outer_merged.replace(find_replace, inplace=True)

#project_length
outer_merged['project_length_code'] = outer_merged['project_length']
find_replace = {"project_length_code" : {"NA": 0, "Unknown": 0, "Hours": 1, "Days": 24, "Weeks": 168, "Months": 720}} #in hours
outer_merged.replace(find_replace, inplace=True)

# %%
#normalization
from sklearn.preprocessing import MinMaxScaler

min_max_scaler = MinMaxScaler() 
column_names_to_normalize = ['changed_bounty_value','github_comments','increased_bounty_times','description_length','duration_create_to_expire','number_of_activities','number_of_fulfillments','number_of_interests','token_value_in_usdt','value_in_eth','value_in_token','value_in_usdt','value_in_usdt_now','duration_create_to_done','duration_create_to_firstAct','duration_create_to_killed','duration_create_to_lastAct','duration_create_to_new_bounty','duration_create_to_start','duration_create_to_stop','duration_create_to_submitted','duration_create_to_worker_applied','number_of_user_in_activities']
x = outer_merged[column_names_to_normalize].values
x_scaled = min_max_scaler.fit_transform(x)
outer_merged_temp = pd.DataFrame(x_scaled, columns=column_names_to_normalize, index = outer_merged.index)
outer_merged[column_names_to_normalize] = outer_merged_temp

# %%
pd.set_option('display.max_columns', None)
outer_merged_temp.describe()
outer_merged_temp.shape
outer_merged.describe()
outer_merged.shape
# Out:
#        changed_bounty_value  github_comments  increased_bounty_times  \
# count           4584.000000      4584.000000             4584.000000
# mean               0.000841         0.084412                0.004005
# std                0.018127         0.117538                0.025336
# min                0.000000         0.000000                0.000000
# 25%                0.000045         0.010638                0.000000
# 50%                0.000045         0.042553                0.000000
# 75%                0.000045         0.117021                0.000000
# max                1.000000         1.000000                1.000000
#
#        description_length  duration_create_to_expire  number_of_activities  \
# count         4584.000000                4584.000000           4584.000000
# mean             0.051541                   0.102374              0.031279
# std              0.056217                   0.274589              0.049440
# min              0.000000                   0.000000              0.000000
# 25%              0.015718                   0.000242              0.012500
# 50%              0.033951                   0.000259              0.020000
# 75%              0.068522                   0.003145              0.032500
# max              1.000000                   1.000000              1.000000
#
#        number_of_fulfillments  number_of_interests  token_value_in_usdt  \
# count             4584.000000          4584.000000          4584.000000
# mean                 0.010140             0.014849             0.007655
# std                  0.039168             0.040416             0.024649
# min                  0.000000             0.000000             0.000000
# 25%                  0.000000             0.006024             0.000028
# 50%                  0.006410             0.006024             0.003430
# 75%                  0.006410             0.012048             0.008937
# max                  1.000000             1.000000             1.000000
#
#        value_in_eth  value_in_token  value_in_usdt  value_in_usdt_now  \
# count   4584.000000    4.584000e+03    4584.000000        4584.000000
# mean       0.000589    5.869119e-04       0.000609           0.000620
# std        0.020894    1.702679e-02       0.020923           0.020905
# min        0.000000    0.000000e+00       0.000000           0.000000
# 25%        0.000010    1.361610e-08       0.000012           0.000010
# 50%        0.000026    1.270836e-07       0.000029           0.000026
# 75%        0.000071    1.089288e-05       0.000079           0.000079
# max        1.000000    1.000000e+00       1.000000           1.000000
#
#        duration_create_to_done  duration_create_to_firstAct  \
# count              4584.000000                  4584.000000
# mean                  0.032849                     0.003017
# std                   0.075719                     0.029698
# min                   0.000000                     0.000000
# 25%                   0.000000                     0.001304
# 50%                   0.003132                     0.001306
# 75%                   0.031154                     0.001310
# max                   1.000000                     1.000000
#
#        duration_create_to_killed  duration_create_to_lastAct  \
# count                4584.000000                 4584.000000
# mean                    0.023449                    0.219392
# std                     0.086083                    0.226041
# min                     0.000000                    0.000000
# 25%                     0.000000                    0.023263
# 50%                     0.000000                    0.118539
# 75%                     0.000000                    0.393087
# max                     1.000000                    1.000000
#
#        duration_create_to_new_bounty  duration_create_to_start  \
# count                    4584.000000               4584.000000
# mean                        0.362647                  0.006785
# std                         0.046084                  0.040718
# min                         0.000000                  0.000000
# 25%                         0.355253                  0.000000
# 50%                         0.355684                  0.000000
# 75%                         0.356496                  0.000562
# max                         1.000000                  1.000000
#
#        duration_create_to_stop  duration_create_to_submitted  \
# count              4584.000000                   4584.000000
# mean                  0.016800                      0.078956
# std                   0.061074                      0.187339
# min                   0.000000                      0.000000
# 25%                   0.000000                      0.000000
# 50%                   0.000000                      0.005193
# 75%                   0.007055                      0.030450
# max                   1.000000                      1.000000
#
#        duration_create_to_worker_applied  number_of_user_in_activities
# count                        4584.000000                   4584.000000
# mean                            0.009370                      0.025320
# std                             0.051110                      0.045570
# min                             0.000000                      0.000000
# 25%                             0.000831                      0.011765
# 50%                             0.000835                      0.017647
# 75%                             0.001513                      0.023529
# max                             1.000000                      1.000000
# (4584, 23)
#        description_length  duration_create_to_expire  github_comments  \
# count         4584.000000                4584.000000      4584.000000
# mean             0.051541                   0.102374         0.084412
# std              0.056217                   0.274589         0.117538
# min              0.000000                   0.000000         0.000000
# 25%              0.015718                   0.000242         0.010638
# 50%              0.033951                   0.000259         0.042553
# 75%              0.068522                   0.003145         0.117021
# max              1.000000                   1.000000         1.000000
#
#        github_issue_number      is_paid   is_success  number_of_activities  \
# count         4.584000e+03  4584.000000  4584.000000           4584.000000
# mean          2.752041e+03     0.580716     0.580716              0.031279
# std           1.214674e+05     0.493496     0.493496              0.049440
# min           0.000000e+00     0.000000     0.000000              0.000000
#        increased_bounty_times  changed_bounty_value  experience_level_code  \
# count             4584.000000           4584.000000            4584.000000
# mean                 0.004005              0.000841               1.578098
# std                  0.025336              0.018127               0.903123
# min                  0.000000              0.000000               0.000000
# 25%                  0.000000              0.000045               1.000000
# 50%                  0.000000              0.000045               2.000000
# 75%                  0.000000              0.000045               2.000000
# max                  1.000000              1.000000               3.000000
#
#        project_length_code
# count          4584.000000
# mean             20.155541
# std              62.679123
# min               0.000000
# 25%               1.000000
# 50%               1.000000
# 75%              24.000000
# max             720.000000
# (4584, 87)

# %%
#all features used in Table 2 Feature Description
columns_temp = ['pk','is_success','duration_create_to_expire','value_in_eth','value_in_token','value_in_usdt','value_in_usdt_now',
                'project_length_code','experience_level_code','project_type',
                'github_comments','number_of_activities','number_of_fulfillments','number_of_interests',
                'description_length','duration_create_to_done','duration_create_to_firstAct','duration_create_to_lastAct',
                'duration_create_to_submitted','duration_create_to_killed','duration_create_to_new_bounty',
                'duration_create_to_start','duration_create_to_stop','duration_create_to_worker_applied',
                'number_of_user_in_activities','changed_bounty_value','increased_bounty_times','bounty_type','token_name',
                'firstAct_activity_type','lastAct_activity_type']

outer_merged_temp = outer_merged[columns_temp]
outer_merged = outer_merged_temp

# %%
outer_merged.describe()
outer_merged.shape
# Out:
#                  pk   is_success  duration_create_to_expire  value_in_eth  \
# count   4584.000000  4584.000000                4584.000000   4584.000000
# mean   14940.176483     0.580716                   0.102374      0.000589
# std     6748.159187     0.493496                   0.274589      0.020894
# min       11.000000     0.000000                   0.000000      0.000000
# 25%    10345.750000     0.000000                   0.000242      0.000010
# 50%    14574.500000     1.000000                   0.000259      0.000026
# 75%    21592.000000     1.000000                   0.003145      0.000071
# max    24558.000000     1.000000                   1.000000      1.000000
#
#        value_in_token  value_in_usdt  value_in_usdt_now  project_length_code  \
# count    4.584000e+03    4584.000000        4584.000000          4584.000000
# mean     5.869119e-04       0.000609           0.000620            20.155541
# std      1.702679e-02       0.020923           0.020905            62.679123
# min      0.000000e+00       0.000000           0.000000             0.000000
# 25%      1.361610e-08       0.000012           0.000010             1.000000
# 50%      1.270836e-07       0.000029           0.000026             1.000000
# 75%      1.089288e-05       0.000079           0.000079            24.000000
# max      1.000000e+00       1.000000           1.000000           720.000000
#
#        experience_level_code  github_comments  number_of_activities  \
# count            4584.000000      4584.000000           4584.000000
# mean                1.578098         0.084412              0.031279
# std                 0.903123         0.117538              0.049440
# min                 0.000000         0.000000              0.000000
# 25%                 1.000000         0.010638              0.012500
# 50%                 2.000000         0.042553              0.020000
# 75%                 2.000000         0.117021              0.032500
# max                 3.000000         1.000000              1.000000
#
#        number_of_fulfillments  number_of_interests  description_length  \
# count             4584.000000          4584.000000         4584.000000
# mean                 0.010140             0.014849            0.051541
# std                  0.039168             0.040416            0.056217
# min                  0.000000             0.000000            0.000000
# 25%                  0.000000             0.006024            0.015718
# 50%                  0.006410             0.006024            0.033951
# 75%                  0.006410             0.012048            0.068522
# max                  1.000000             1.000000            1.000000
#
#        duration_create_to_done  duration_create_to_firstAct  \
# count              4584.000000                  4584.000000
# mean                  0.032849                     0.003017
# std                   0.075719                     0.029698
# min                   0.000000                     0.000000
# 25%                   0.000000                     0.001304
# 50%                   0.003132                     0.001306
# 75%                   0.031154                     0.001310
# max                   1.000000                     1.000000
#
#        duration_create_to_lastAct  duration_create_to_submitted  \
# count                 4584.000000                   4584.000000
# mean                     0.219392                      0.078956
# std                      0.226041                      0.187339
# min                      0.000000                      0.000000
# 25%                      0.023263                      0.000000
# 50%                      0.118539                      0.005193
# 75%                      0.393087                      0.030450
# max                      1.000000                      1.000000
#
#        duration_create_to_killed  duration_create_to_new_bounty  \
# count                4584.000000                    4584.000000
# mean                    0.023449                       0.362647
# std                     0.086083                       0.046084
# min                     0.000000                       0.000000
# 25%                     0.000000                       0.355253
# 50%                     0.000000                       0.355684
# 75%                     0.000000                       0.356496
# max                     1.000000                       1.000000
#
#        duration_create_to_start  duration_create_to_stop  \
# count               4584.000000              4584.000000
# mean                   0.006785                 0.016800
# std                    0.040718                 0.061074
# min                    0.000000                 0.000000
# 25%                    0.000000                 0.000000
# 50%                    0.000000                 0.000000
# 75%                    0.000562                 0.007055
# max                    1.000000                 1.000000
#
#        duration_create_to_worker_applied  number_of_user_in_activities  \
# count                        4584.000000                   4584.000000
# mean                            0.009370                      0.025320
# std                             0.051110                      0.045570
# min                             0.000000                      0.000000
# 25%                             0.000831                      0.011765
# 50%                             0.000835                      0.017647
# 75%                             0.001513                      0.023529
# max                             1.000000                      1.000000
#
#        changed_bounty_value  increased_bounty_times
# count           4584.000000             4584.000000
# mean               0.000841                0.004005
# std                0.018127                0.025336
# min                0.000000                0.000000
# 25%                0.000045                0.000000
# 50%                0.000045                0.000000
# 75%                0.000045                0.000000
# max                1.000000                1.000000
# (4584, 31)

# %%
#Making categorical variables into numeric representation
feature_to_trans_set1 = ['bounty_type','token_name','project_type','firstAct_activity_type','lastAct_activity_type']

new_raw_data_set1 = pd.get_dummies(outer_merged, columns = feature_to_trans_set1)

# %%
#bootstrap sampling

from random import sample

bootstrapped_set1 = new_raw_data_set1.sample(n=4584, replace=True)
bootstrapped_set1.shape

repeats = bootstrapped_set1['pk'].value_counts()
repeats.head()

new_raw_data_set1.describe()
bootstrapped_set1.describe()
# Out:
# (4584, 154)
# 23938    6
# 16373    6
# 3030     5
# 23917    5
# 15693    5
# Name: pk, dtype: int64
#                  pk   is_success  duration_create_to_expire  value_in_eth  \
# count   4584.000000  4584.000000                4584.000000   4584.000000
# mean   14940.176483     0.580716                   0.102374      0.000589
# std     6748.159187     0.493496                   0.274589      0.020894
# min       11.000000     0.000000                   0.000000      0.000000
# 25%    10345.750000     0.000000                   0.000242      0.000010
# 50%    14574.500000     1.000000                   0.000259      0.000026
# 75%    21592.000000     1.000000                   0.003145      0.000071
# max    24558.000000     1.000000                   1.000000      1.000000
#
#        value_in_token  value_in_usdt  value_in_usdt_now  project_length_code  \
# count    4.584000e+03    4584.000000        4584.000000          4584.000000
# mean     5.869119e-04       0.000609           0.000620            20.155541
# std      1.702679e-02       0.020923           0.020905            62.679123
# min      0.000000e+00       0.000000           0.000000             0.000000
# 25%      1.361610e-08       0.000012           0.000010             1.000000
# 50%      1.270836e-07       0.000029           0.000026             1.000000
# 75%      1.089288e-05       0.000079           0.000079            24.000000
# max      1.000000e+00       1.000000           1.000000           720.000000
#
#        experience_level_code  github_comments  number_of_activities  \
# count            4584.000000      4584.000000           4584.000000
# mean                1.578098         0.084412              0.031279
# std                 0.903123         0.117538              0.049440
# min                 0.000000         0.000000              0.000000
# 25%                 1.000000         0.010638              0.012500
# 50%                 2.000000         0.042553              0.020000
# 75%                 2.000000         0.117021              0.032500
# max                 3.000000         1.000000              1.000000
#
#        number_of_fulfillments  number_of_interests  description_length  \
# count             4584.000000          4584.000000         4584.000000
# mean                 0.010140             0.014849            0.051541
# std                  0.039168             0.040416            0.056217
# min                  0.000000             0.000000            0.000000
# 25%                  0.000000             0.006024            0.015718
# 50%                  0.006410             0.006024            0.033951
# 75%                  0.006410             0.012048            0.068522
# max                  1.000000             1.000000            1.000000
#
#        duration_create_to_done  duration_create_to_firstAct  \
# count              4584.000000                  4584.000000
# mean                  0.032849                     0.003017
# std                   0.075719                     0.029698
# min                   0.000000                     0.000000
# 25%                   0.000000                     0.001304
# 50%                   0.003132                     0.001306
# 75%                   0.031154                     0.001310
# max                   1.000000                     1.000000
#
#        duration_create_to_lastAct  duration_create_to_submitted  \
# count                 4584.000000                   4584.000000
# mean                     0.219392                      0.078956
# std                      0.226041                      0.187339
# min                      0.000000                      0.000000
# 25%                      0.023263                      0.000000
# 50%                      0.118539                      0.005193
# 75%                      0.393087                      0.030450
# max                      1.000000                      1.000000
#
#        duration_create_to_killed  duration_create_to_new_bounty  \
# count                4584.000000                    4584.000000
# mean                    0.023449                       0.362647
# std                     0.086083                       0.046084
# min                     0.000000                       0.000000
# 25%                     0.000000                       0.355253
# 50%                     0.000000                       0.355684
# 75%                     0.000000                       0.356496
# max                     1.000000                       1.000000
#
#        duration_create_to_start  duration_create_to_stop  \
# count               4584.000000              4584.000000
# mean                   0.006785                 0.016800
# std                    0.040718                 0.061074
# min                    0.000000                 0.000000
# 25%                    0.000000                 0.000000
# 50%                    0.000000                 0.000000
# 75%                    0.000562                 0.007055
# max                    1.000000                 1.000000
#
#        duration_create_to_worker_applied  number_of_user_in_activities  \
# count                        4584.000000                   4584.000000
# mean                            0.009370                      0.025320
# std                             0.051110                      0.045570
# min                             0.000000                      0.000000
# 25%                             0.000831                      0.011765
# 50%                             0.000835                      0.017647
# 75%                             0.001513                      0.023529
# max                             1.000000                      1.000000
#
#        changed_bounty_value  increased_bounty_times  bounty_type_Bug  \
# count           4584.000000             4584.000000      4584.000000
# mean               0.000841                0.004005         0.072644
# std                0.018127                0.025336         0.259580
# min                0.000000                0.000000         0.000000
# 25%                0.000045                0.000000         0.000000
# 50%                0.000045                0.000000         0.000000
# 75%                0.000045                0.000000         0.000000
# max                1.000000                1.000000         1.000000
#
#        bounty_type_Code Review  bounty_type_Design  bounty_type_Documentation  \
# count              4584.000000         4584.000000                4584.000000
# mean                  0.004363            0.010035                   0.048866
# std                   0.065916            0.099681                   0.215611
# min                   0.000000            0.000000                   0.000000
# std          0.033012         0.119137         0.069118         0.014770
# min          0.000000         0.000000         0.000000         0.000000
# 25%          0.000000         0.000000         0.000000         0.000000
# 50%          0.000000         0.000000         0.000000         0.000000
# 75%          0.000000         0.000000         0.000000         0.000000
# max          1.000000         1.000000         1.000000         1.000000
#
#        token_name_WYV  token_name_XRT  token_name_ZIL  token_name_ZRX  \
# count     4584.000000     4584.000000     4584.000000     4584.000000
# mean         0.001091        0.000218        0.001527        0.001091
# std          0.033012        0.014770        0.039052        0.033012
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000000        0.000000        0.000000        0.000000
# 50%          0.000000        0.000000        0.000000        0.000000
# 75%          0.000000        0.000000        0.000000        0.000000
# max          1.000000        1.000000        1.000000        1.000000
#
#        token_name_aDAI  token_name_cUSD  token_name_wNXM  \
# count      4584.000000      4584.000000      4584.000000
# mean          0.001309         0.000218         0.000436
# std           0.036159         0.014770         0.020886
# min           0.000000         0.000000         0.000000
# 25%           0.000000         0.000000         0.000000
# 50%           0.000000         0.000000         0.000000
# 75%           0.000000         0.000000         0.000000
# max           1.000000         1.000000         1.000000
#
#        project_type_contest  project_type_cooperative  \
# count           4584.000000               4584.000000
# mean               0.188045                  0.090532
# std                0.390791                  0.286974
# min                0.000000                  0.000000
# 25%                0.000000                  0.000000
# 50%                0.000000                  0.000000
# 75%                0.000000                  0.000000
# max                1.000000                  1.000000
#
#        project_type_traditional  firstAct_activity_type_NA  \
# count               4584.000000                4584.000000
# mean                   0.721422                   0.005890
# std                    0.448348                   0.076529
# min                    0.000000                   0.000000
# 25%                    0.000000                   0.000000
# 50%                    1.000000                   0.000000
# 75%                    1.000000                   0.000000
# max                    1.000000                   1.000000
#
#        firstAct_activity_type_bounty_changed  \
# count                            4584.000000
# mean                                0.001309
# std                                 0.036159
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        firstAct_activity_type_extend_expiration  \
# count                               4584.000000
# mean                                   0.000218
# std                                    0.014770
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    0.000000
# 75%                                    0.000000
# max                                    1.000000
#
#        firstAct_activity_type_killed_bounty  \
# count                           4584.000000
# mean                               0.002400
# std                                0.048933
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                1.000000
#
#        firstAct_activity_type_new_bounty  firstAct_activity_type_start_work  \
# count                        4584.000000                        4584.000000
# mean                            0.955716                           0.014616
# std                             0.205749                           0.120023
# min                             0.000000                           0.000000
# 25%                             1.000000                           0.000000
# 50%                             1.000000                           0.000000
# 75%                             1.000000                           0.000000
# max                             1.000000                           1.000000
#
#        firstAct_activity_type_unknown_event  firstAct_activity_type_work_done  \
# count                           4584.000000                       4584.000000
# mean                               0.003927                          0.000218
# std                                0.062547                          0.014770
# min                                0.000000                          0.000000
# 25%                                0.000000                          0.000000
# 50%                                0.000000                          0.000000
# 75%                                0.000000                          0.000000
# max                                1.000000                          1.000000
#
#        firstAct_activity_type_work_submitted  \
# count                            4584.000000
# mean                                0.002400
# std                                 0.048933
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        firstAct_activity_type_worker_applied  lastAct_activity_type_NA  \
# count                            4584.000000               4584.000000
# mean                                0.013307                  0.005890
# std                                 0.114599                  0.076529
# min                                 0.000000                  0.000000
# 25%                                 0.000000                  0.000000
# 50%                                 0.000000                  0.000000
# 75%                                 0.000000                  0.000000
# max                                 1.000000                  1.000000
#
#        lastAct_activity_type_bounty_abandonment_escalation_to_mods  \
# count                                         4584.00000
# mean                                             0.00829
# std                                              0.09068
# min                                              0.00000
# 25%                                              0.00000
# 50%                                              0.00000
# 75%                                              0.00000
# max                                              1.00000
#
#        lastAct_activity_type_bounty_abandonment_warning  \
# count                                       4584.000000
# mean                                           0.005454
# std                                            0.073656
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            0.000000
# 75%                                            0.000000
# max                                            1.000000
#
#        lastAct_activity_type_bounty_changed  \
# count                           4584.000000
# mean                               0.004799
# std                                0.069118
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                1.000000
#
#        lastAct_activity_type_bounty_removed_by_staff  \
# count                                    4584.000000
# mean                                        0.000218
# std                                         0.014770
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         1.000000
#
#        lastAct_activity_type_extend_expiration  \
# count                              4584.000000
# mean                                  0.004581
# std                                   0.067536
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   1.000000
#
#        lastAct_activity_type_increased_bounty  \
# count                             4584.000000
# mean                                 0.000436
# std                                  0.020886
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        lastAct_activity_type_killed_bounty  lastAct_activity_type_new_bounty  \
# count                          4584.000000                       4584.000000
# mean                              0.121291                          0.011344
# std                               0.326501                          0.105913
# min                               0.000000                          0.000000
# 25%                               0.000000                          0.000000
# 50%                               0.000000                          0.000000
# 75%                               0.000000                          0.000000
# max                               1.000000                          1.000000
#
#        lastAct_activity_type_new_crowdfund  lastAct_activity_type_new_kudos  \
# count                          4584.000000                      4584.000000
# mean                              0.000218                         0.001963
# std                               0.014770                         0.044271
# min                               0.000000                         0.000000
# 25%                               0.000000                         0.000000
# 50%                               0.000000                         0.000000
# 75%                               0.000000                         0.000000
# max                               1.000000                         1.000000
#
#        lastAct_activity_type_new_tip  lastAct_activity_type_receive_kudos  \
# count                    4584.000000                          4584.000000
# mean                        0.080061                             0.000218
# std                         0.271417                             0.014770
# min                         0.000000                             0.000000
# 25%                         0.000000                             0.000000
# 50%                         0.000000                             0.000000
# 75%                         0.000000                             0.000000
# max                         1.000000                             1.000000
#
#        lastAct_activity_type_receive_tip  lastAct_activity_type_start_work  \
# count                        4584.000000                       4584.000000
# mean                            0.020942                          0.017888
# std                             0.143207                          0.132560
# min                             0.000000                          0.000000
# 25%                             0.000000                          0.000000
# 50%                             0.000000                          0.000000
# 75%                             0.000000                          0.000000
# max                             1.000000                          1.000000
#
#        lastAct_activity_type_stop_work  lastAct_activity_type_unknown_event  \
# count                      4584.000000                          4584.000000
# mean                          0.059555                             0.114311
# std                           0.236686                             0.318223
# min                           0.000000                             0.000000
# 25%                           0.000000                             0.000000
# 50%                           0.000000                             0.000000
# 75%                           0.000000                             0.000000
# max                           1.000000                             1.000000
#
#        lastAct_activity_type_work_done  lastAct_activity_type_work_submitted  \
# count                      4584.000000                           4584.000000
# mean                          0.229058                              0.294066
# std                           0.420272                              0.455672
# min                           0.000000                              0.000000
# 25%                           0.000000                              0.000000
# 50%                           0.000000                              0.000000
# 75%                           0.000000                              1.000000
# max                           1.000000                              1.000000
#
#        lastAct_activity_type_worker_applied  \
# count                           4584.000000
# mean                               0.014616
# std                                0.120023
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                1.000000
#
#        lastAct_activity_type_worker_approved  \
# count                            4584.000000
# mean                                0.002400
# std                                 0.048933
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        lastAct_activity_type_worker_rejected
# count                            4584.000000
# mean                                0.002400
# std                                 0.048933
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#                  pk   is_success  duration_create_to_expire  value_in_eth  \
# count   4584.000000  4584.000000                4584.000000   4584.000000
# mean   14880.768761     0.576353                   0.104225      0.001022
# std     6829.278434     0.494190                   0.276912      0.029533
# min       11.000000     0.000000                   0.000000      0.000000
# 25%    10330.750000     0.000000                   0.000242      0.000010
# 50%    14574.000000     1.000000                   0.000259      0.000026
# 75%    21504.000000     1.000000                   0.003145      0.000071
# max    24558.000000     1.000000                   1.000000      1.000000
#
#        value_in_token  value_in_usdt  value_in_usdt_now  project_length_code  \
# count    4.584000e+03    4584.000000        4584.000000          4584.000000
# mean     4.021546e-04       0.001053           0.001046            19.829625
# std      1.541937e-02       0.029555           0.029540            63.407520
# min      0.000000e+00       0.000000           0.000000             0.000000
# 25%      1.361610e-08       0.000012           0.000010             1.000000
# 50%      1.319400e-07       0.000029           0.000026             1.000000
# 75%      1.188821e-05       0.000078           0.000073            24.000000
# max      1.000000e+00       1.000000           1.000000           720.000000
#
#        experience_level_code  github_comments  number_of_activities  \
# count            4584.000000      4584.000000           4584.000000
# mean                1.606457         0.085213              0.031132
# std                 0.890962         0.115305              0.051230
# min                 0.000000         0.000000              0.000000
# 25%                 1.000000         0.010638              0.012500
# 50%                 2.000000         0.042553              0.020000
# 75%                 2.000000         0.117021              0.032500
# max                 3.000000         0.978723              1.000000
#
#        number_of_fulfillments  number_of_interests  description_length  \
# count             4584.000000          4584.000000         4584.000000
# mean                 0.010245             0.014629            0.051259
# std                  0.041966             0.040124            0.058421
# min                  0.000000             0.000000            0.000000
# 25%                  0.000000             0.006024            0.016143
# 50%                  0.006410             0.006024            0.033293
# 75%                  0.006410             0.012048            0.068058
# max                  1.000000             1.000000            1.000000
#
#        duration_create_to_done  duration_create_to_firstAct  \
# count              4584.000000                  4584.000000
# mean                  0.032906                     0.003336
# std                   0.074226                     0.035318
# min                   0.000000                     0.000002
# 25%                   0.000000                     0.001304
# 50%                   0.003042                     0.001306
# 75%                   0.031301                     0.001310
# max                   1.000000                     1.000000
#
#        duration_create_to_lastAct  duration_create_to_submitted  \
# count                 4584.000000                   4584.000000
# mean                     0.221904                      0.078939
# std                      0.229249                      0.186697
# min                      0.000000                      0.000000
# 25%                      0.022014                      0.000000
# 50%                      0.125423                      0.004929
# 75%                      0.392171                      0.031778
# max                      1.000000                      1.000000
#
#        duration_create_to_killed  duration_create_to_new_bounty  \
# count                 4584.00000                    4584.000000
# mean                     0.02361                       0.362879
# std                      0.08748                       0.044951
# min                      0.00000                       0.000413
# 25%                      0.00000                       0.355253
# 50%                      0.00000                       0.355658
# 75%                      0.00000                       0.356402
# max                      1.00000                       0.994380
#
#        duration_create_to_start  duration_create_to_stop  \
# count               4584.000000              4584.000000
# mean                   0.007681                 0.016877
# std                    0.048642                 0.061961
# min                    0.000000                 0.000000
# 25%                    0.000000                 0.000000
# 50%                    0.000000                 0.000000
# 75%                    0.000587                 0.005718
# max                    1.000000                 1.000000
#
#        duration_create_to_worker_applied  number_of_user_in_activities  \
# count                        4584.000000                   4584.000000
# mean                            0.010164                      0.025184
# std                             0.056939                      0.047019
# min                             0.000831                      0.000000
# 25%                             0.000831                      0.011765
# 50%                             0.000835                      0.017647
# 75%                             0.001524                      0.023529
# max                             1.000000                      1.000000
#
#        changed_bounty_value  increased_bounty_times  bounty_type_Bug  \
# count           4584.000000             4584.000000      4584.000000
# mean               0.001028                0.004270         0.069808
# std                0.023635                0.027868         0.254851
# min                0.000000                0.000000         0.000000
# 25%                0.000045                0.000000         0.000000
# 50%                0.000045                0.000000         0.000000
# 75%                0.000045                0.000000         0.000000
# max                1.000000                1.000000         1.000000
#
#        bounty_type_Code Review  bounty_type_Design  bounty_type_Documentation  \
# count              4584.000000         4584.000000                4584.000000
# mean                  0.004363            0.008944                   0.046248
# std                   0.065916            0.094160                   0.210044
# min                   0.000000            0.000000                   0.000000
# 25%                   0.000000            0.000000                   0.000000
# 50%                   0.000000            0.000000                   0.000000
# 75%                   0.000000            0.000000                   0.000000
# max                   1.000000            1.000000                   1.000000
#
#        bounty_type_Feature  bounty_type_Improvement  bounty_type_NA  \
# count          4584.000000              4584.000000     4584.000000
# mean              0.404014                 0.148560        0.213569
# std               0.490754                 0.355693        0.409871
# min               0.000000                 0.000000        0.000000
# 25%               0.000000                 0.000000        0.000000
# 50%               0.000000                 0.000000        0.000000
# 75%               1.000000                 0.000000        0.000000
# max               1.000000                 1.000000        1.000000
#
#        bounty_type_Other  bounty_type_Security  token_name_0xBTC  \
# count        4584.000000           4584.000000            4584.0
# mean            0.083551              0.020942               0.0
# std             0.276744              0.143207               0.0
# min             0.000000              0.000000               0.0
# 25%             0.000000              0.000000               0.0
# 50%             0.000000              0.000000               0.0
# 75%             0.000000              0.000000               0.0
# max             1.000000              1.000000               0.0
#
#        token_name_AEUR  token_name_AION  token_name_ALEX  token_name_ANT  \
# count      4584.000000      4584.000000           4584.0     4584.000000
# mean          0.000436         0.001309              0.0        0.004363
# std           0.020886         0.036159              0.0        0.065916
# min           0.000000         0.000000              0.0        0.000000
# 25%           0.000000         0.000000              0.0        0.000000
# 50%           0.000000         0.000000              0.0        0.000000
# 75%           0.000000         0.000000              0.0        0.000000
# max           1.000000         1.000000              0.0        1.000000
#
#        token_name_AVO  token_name_BAND  token_name_BLZ  token_name_BNB  \
# count     4584.000000      4584.000000     4584.000000          4584.0
# mean         0.000654         0.000218        0.002400             0.0
# std          0.025577         0.014770        0.048933             0.0
# min          0.000000         0.000000        0.000000             0.0
# 25%          0.000000         0.000000        0.000000             0.0
# 50%          0.000000         0.000000        0.000000             0.0
# 75%          0.000000         0.000000        0.000000             0.0
# max          1.000000         1.000000        1.000000             0.0
#
#        token_name_BNT  token_name_BORIS  token_name_BRLN  token_name_BTC  \
# count     4584.000000       4584.000000      4584.000000     4584.000000
# mean         0.000218          0.000436         0.000218        0.001309
# std          0.014770          0.020886         0.014770        0.036159
# min          0.000000          0.000000         0.000000        0.000000
# 25%          0.000000          0.000000         0.000000        0.000000
# 50%          0.000000          0.000000         0.000000        0.000000
# 75%          0.000000          0.000000         0.000000        0.000000
# max          1.000000          1.000000         1.000000        1.000000
#
#        token_name_CBTX  token_name_CHI  token_name_CLN  token_name_COIN  \
# count      4584.000000     4584.000000     4584.000000      4584.000000
# mean          0.001309        0.000654        0.002182         0.000218
# std           0.036159        0.025577        0.046661         0.014770
# min           0.000000        0.000000        0.000000         0.000000
# 25%           0.000000        0.000000        0.000000         0.000000
# 50%           0.000000        0.000000        0.000000         0.000000
# 75%           0.000000        0.000000        0.000000         0.000000
# max           1.000000        1.000000        1.000000         1.000000
#
#        token_name_DAI  token_name_DAT  token_name_DATA  token_name_DIA  \
# count     4584.000000     4584.000000           4584.0     4584.000000
# mean         0.267234        0.001309              0.0        0.003490
# std          0.442564        0.036159              0.0        0.058983
# min          0.000000        0.000000              0.0        0.000000
# 25%          0.000000        0.000000              0.0        0.000000
# 50%          0.000000        0.000000              0.0        0.000000
# 75%          1.000000        0.000000              0.0        0.000000
# max          1.000000        1.000000              0.0        1.000000
#
#        token_name_DOT  token_name_ENG  token_name_ETC  token_name_ETH  \
# count     4584.000000     4584.000000     4584.000000     4584.000000
# mean         0.005672        0.001963        0.004581        0.520942
# std          0.075106        0.044271        0.067536        0.499616
# ...
# count            4584.0      4584.000000     4584.000000      4584.000000
# mean                0.0         0.000654        0.002400         0.001309
# std                 0.0         0.025577        0.048933         0.036159
# min                 0.0         0.000000        0.000000         0.000000
# 25%                 0.0         0.000000        0.000000         0.000000
# 50%                 0.0         0.000000        0.000000         0.000000
# 75%                 0.0         0.000000        0.000000         0.000000
# max                 0.0         1.000000        1.000000         1.000000
#
#        token_name_USD  token_name_USDC  token_name_USDT  token_name_WBTC  \
# count     4584.000000      4584.000000      4584.000000      4584.000000
# mean         0.001309         0.013307         0.004581         0.000436
# std          0.036159         0.114599         0.067536         0.020886
# min          0.000000         0.000000         0.000000         0.000000
# 25%          0.000000         0.000000         0.000000         0.000000
# 50%          0.000000         0.000000         0.000000         0.000000
# 75%          0.000000         0.000000         0.000000         0.000000
# max          1.000000         1.000000         1.000000         1.000000
#
#        token_name_WYV  token_name_XRT  token_name_ZIL  token_name_ZRX  \
# count     4584.000000     4584.000000     4584.000000     4584.000000
# mean         0.000654        0.000218        0.001745        0.001745
# std          0.025577        0.014770        0.041744        0.041744
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000000        0.000000        0.000000        0.000000
# 50%          0.000000        0.000000        0.000000        0.000000
# 75%          0.000000        0.000000        0.000000        0.000000
# max          1.000000        1.000000        1.000000        1.000000
#
#        token_name_aDAI  token_name_cUSD  token_name_wNXM  \
# count      4584.000000      4584.000000           4584.0
# mean          0.001309         0.000873              0.0
# std           0.036159         0.029530              0.0
# min           0.000000         0.000000              0.0
# 25%           0.000000         0.000000              0.0
# 50%           0.000000         0.000000              0.0
# 75%           0.000000         0.000000              0.0
# max           1.000000         1.000000              0.0
#
#        project_type_contest  project_type_cooperative  \
# count           4584.000000               4584.000000
# mean               0.182810                  0.096204
# std                0.386553                  0.294903
# min                0.000000                  0.000000
# 25%                0.000000                  0.000000
# 50%                0.000000                  0.000000
# 75%                0.000000                  0.000000
# max                1.000000                  1.000000
#
#        project_type_traditional  firstAct_activity_type_NA  \
# count               4584.000000                4584.000000
# mean                   0.720986                   0.006545
# std                    0.448563                   0.080642
# min                    0.000000                   0.000000
# 25%                    0.000000                   0.000000
# 50%                    1.000000                   0.000000
# 75%                    1.000000                   0.000000
# max                    1.000000                   1.000000
#
#        firstAct_activity_type_bounty_changed  \
# count                            4584.000000
# mean                                0.000654
# std                                 0.025577
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        firstAct_activity_type_extend_expiration  \
# count                               4584.000000
# mean                                   0.000218
# std                                    0.014770
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    0.000000
# 75%                                    0.000000
# max                                    1.000000
#
#        firstAct_activity_type_killed_bounty  \
# count                           4584.000000
# mean                               0.001527
# std                                0.039052
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                1.000000
#
#        firstAct_activity_type_new_bounty  firstAct_activity_type_start_work  \
# count                        4584.000000                        4584.000000
# mean                            0.953970                           0.016798
# std                             0.209572                           0.128526
# min                             0.000000                           0.000000
# 25%                             1.000000                           0.000000
# 50%                             1.000000                           0.000000
# 75%                             1.000000                           0.000000
# max                             1.000000                           1.000000
#
#        firstAct_activity_type_unknown_event  firstAct_activity_type_work_done  \
# count                           4584.000000                       4584.000000
# mean                               0.004145                          0.000654
# std                                0.064254                          0.025577
# min                                0.000000                          0.000000
# 25%                                0.000000                          0.000000
# 50%                                0.000000                          0.000000
# 75%                                0.000000                          0.000000
# max                                1.000000                          1.000000
#
#        firstAct_activity_type_work_submitted  \
# count                            4584.000000
# mean                                0.002836
# std                                 0.053184
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        firstAct_activity_type_worker_applied  lastAct_activity_type_NA  \
# count                            4584.000000               4584.000000
# mean                                0.012653                  0.006545
# std                                 0.111783                  0.080642
# min                                 0.000000                  0.000000
# 25%                                 0.000000                  0.000000
# 50%                                 0.000000                  0.000000
# 75%                                 0.000000                  0.000000
# max                                 1.000000                  1.000000
#
#        lastAct_activity_type_bounty_abandonment_escalation_to_mods  \
# count                                        4584.000000
# mean                                            0.006545
# std                                             0.080642
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        lastAct_activity_type_bounty_abandonment_warning  \
# count                                       4584.000000
# mean                                           0.006981
# std                                            0.083268
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            0.000000
# 75%                                            0.000000
# max                                            1.000000
#
#        lastAct_activity_type_bounty_changed  \
# count                           4584.000000
# mean                               0.004363
# std                                0.065916
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                1.000000
#
#        lastAct_activity_type_bounty_removed_by_staff  \
# count                                    4584.000000
# mean                                        0.000218
# std                                         0.014770
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         1.000000
#
#        lastAct_activity_type_extend_expiration  \
# count                              4584.000000
# mean                                  0.003709
# std                                   0.060791
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   1.000000
#
#        lastAct_activity_type_increased_bounty  \
# count                             4584.000000
# mean                                 0.000436
# std                                  0.020886
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        lastAct_activity_type_killed_bounty  lastAct_activity_type_new_bounty  \
# count                          4584.000000                       4584.000000
# mean                              0.124782                          0.013743
# std                               0.330507                          0.116437
# min                               0.000000                          0.000000
# 25%                               0.000000                          0.000000
# 50%                               0.000000                          0.000000
# 75%                               0.000000                          0.000000
# max                               1.000000                          1.000000
#
#        lastAct_activity_type_new_crowdfund  lastAct_activity_type_new_kudos  \
# count                          4584.000000                      4584.000000
# mean                              0.000218                         0.002400
# std                               0.014770                         0.048933
# min                               0.000000                         0.000000
# 25%                               0.000000                         0.000000
# 50%                               0.000000                         0.000000
# 75%                               0.000000                         0.000000
# max                               1.000000                         1.000000
#
#        lastAct_activity_type_new_tip  lastAct_activity_type_receive_kudos  \
# count                    4584.000000                          4584.000000
# mean                        0.081370                             0.000218
# std                         0.273432                             0.014770
# min                         0.000000                             0.000000
# 25%                         0.000000                             0.000000
# 50%                         0.000000                             0.000000
# 75%                         0.000000                             0.000000
# max                         1.000000                             1.000000
#
#        lastAct_activity_type_receive_tip  lastAct_activity_type_start_work  \
# count                        4584.000000                       4584.000000
# mean                            0.021379                          0.020070
# std                             0.144659                          0.140254
# min                             0.000000                          0.000000
# 25%                             0.000000                          0.000000
# 50%                             0.000000                          0.000000
# 75%                             0.000000                          0.000000
# max                             1.000000                          1.000000
#
#        lastAct_activity_type_stop_work  lastAct_activity_type_unknown_event  \
# count                      4584.000000                          4584.000000
# mean                          0.055628                             0.111038
# std                           0.229227                             0.314214
# min                           0.000000                             0.000000
# 25%                           0.000000                             0.000000
# 50%                           0.000000                             0.000000
# 75%                           0.000000                             0.000000
# max                           1.000000                             1.000000
#
#        lastAct_activity_type_work_done  lastAct_activity_type_work_submitted  \
# count                      4584.000000                           4584.000000
# mean                          0.225349                              0.296466
# std                           0.417858                              0.456749
# min                           0.000000                              0.000000
# 25%                           0.000000                              0.000000
# 50%                           0.000000                              0.000000
# 75%                           0.000000                              1.000000
# max                           1.000000                              1.000000
#
#        lastAct_activity_type_worker_applied  \
# count                           4584.000000
# mean                               0.012653
# std                                0.111783
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                1.000000
#
#        lastAct_activity_type_worker_approved  \
# count                            4584.000000
# mean                                0.002618
# std                                 0.051103
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        lastAct_activity_type_worker_rejected
# count                            4584.000000
# mean                                0.003272
# std                                 0.057116
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000

# %%
#Setting 1

# Split dataset into features and target
y = bootstrapped_set1['is_success']
X = bootstrapped_set1.drop(['is_success','pk'], axis = 1).values

# Split features and target into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3)

# Instantiate and fit the RandomForestClassifier
forest = RandomForestClassifier(criterion='entropy', max_depth=25)
forest.fit(X_train, y_train)

# Make predictions for the test set
y_pred_test = forest.predict(X_test)

# View accuracy score
accuracy_score(y_test, y_pred_test)

# View confusion matrix for test data and predictions
confusion_matrix(y_test, y_pred_test)

# Get and reshape confusion matrix data
matrix = confusion_matrix(y_test, y_pred_test)
matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]

# Build the plot
plt.figure(figsize=(16,7))
sns.heatmap(matrix, annot=True, annot_kws={'size':15},
            cmap=plt.cm.Greens, linewidths=0.2)

plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix for Random Forest Model')
plt.show()

# View the classification report for test data and predictions
print(classification_report(y_test, y_pred_test))

#-----------------------------------------------------------------------------------------------------------
forest.feature_importances_

#-------------------------------------------------------------------------------------------------------------
# Running Feature Importance

fi_col = []
fi = []

for i,column in enumerate(bootstrapped_set1.drop(['is_success','pk'], axis = 1)):
    
    print('The feature importance for {} is : {}'.format(column, forest.feature_importances_[i]))
    
    fi_col.append(column)
    fi.append(forest.feature_importances_[i])
    
# Creating a Dataframe
fi_df = zip(fi_col, fi)
fi_df = pd.DataFrame(fi_df, columns = ['Feature','Feature Importance'])
fi_df.sort_values('Feature Importance', ascending = False).head(20)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=25)
# 0.9796511627906976
# array([[572,  11],
#        [ 17, 776]], dtype=int64)
# <AxesSubplot:>
# Text(0.5, 42.0, 'Predicted label')
# Text(123.0, 0.5, 'True label')
# Text(0.5, 1.0, 'Confusion Matrix for Random Forest Model')
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98
# The feature importance for value_in_token is : 0.010234738942082914
# The feature importance for value_in_usdt is : 0.020822278810768154
# The feature importance for value_in_usdt_now is : 0.015464038332068443
# The feature importance for project_length_code is : 0.005573014376695751
# The feature importance for experience_level_code is : 0.006673832168993779
# The feature importance for github_comments is : 0.013793857894588653
# The feature importance for number_of_activities is : 0.042811636586857806
# The feature importance for number_of_fulfillments is : 0.07945661194646908
# The feature importance for number_of_interests is : 0.036928774595952396
# The feature importance for description_length is : 0.016740339187809507
# The feature importance for duration_create_to_done is : 0.2320711482283651
# The feature importance for duration_create_to_firstAct is : 0.020403493743808076
# The feature importance for duration_create_to_lastAct is : 0.04353970547128105
# The feature importance for duration_create_to_submitted is : 0.07207914019482269
# The feature importance for duration_create_to_killed is : 0.05254737199043137
# The feature importance for duration_create_to_new_bounty is : 0.02974080095927207
# The feature importance for duration_create_to_start is : 0.015476474745995776
# The feature importance for duration_create_to_stop is : 0.022337527055965797
# The feature importance for duration_create_to_worker_applied is : 0.01146096541754293
# The feature importance for number_of_user_in_activities is : 0.023373283708192676
# The feature importance for changed_bounty_value is : 0.0014077274699192143
# The feature importance for increased_bounty_times is : 0.0014156572496810814
# The feature importance for bounty_type_Bug is : 0.001499703920020105
# The feature importance for bounty_type_Code Review is : 0.00013772183313961057
# The feature importance for bounty_type_Design is : 0.00019523368722860468
# The feature importance for bounty_type_Documentation is : 0.0009494225583198308
# The feature importance for bounty_type_Feature is : 0.0029365228846582425
# The feature importance for bounty_type_Improvement is : 0.002067154996326295
# The feature importance for bounty_type_NA is : 0.0030474193136410775
# The feature importance for bounty_type_Other is : 0.0023537294258767346
# The feature importance for bounty_type_Security is : 0.0006230428272559096
# The feature importance for token_name_0xBTC is : 0.0
# The feature importance for token_name_AEUR is : 0.00012433950311244052
# The feature importance for token_name_AION is : 0.00010097977750866616
# The feature importance for token_name_ALEX is : 0.0
# The feature importance for token_name_ANT is : 0.0005515506295487782
# The feature importance for token_name_AVO is : 1.4571439199293535e-05
# The feature importance for token_name_BAND is : 1.5214999288700453e-05
# The feature importance for token_name_BLZ is : 5.72540532182065e-05
# The feature importance for token_name_BNB is : 0.0
# The feature importance for token_name_BNT is : 1.0820273608128028e-06
# The feature importance for token_name_BORIS is : 1.1581424102944528e-05
# The feature importance for token_name_BRLN is : 5.822382725896597e-07
# The feature importance for token_name_BTC is : 3.56095520422148e-05
# The feature importance for token_name_CBTX is : 3.5815635193268036e-06
# The feature importance for token_name_CHI is : 1.2693817983596553e-05
# The feature importance for token_name_CLN is : 1.7736065179417664e-05
# The feature importance for token_name_COIN is : 0.0
# The feature importance for token_name_DAI is : 0.0028996563036812954
# The feature importance for token_name_DAT is : 8.623398518594836e-05
# The feature importance for token_name_DATA is : 0.0
# The feature importance for token_name_DIA is : 0.00019573952632179821
# The feature importance for token_name_DOT is : 0.0005612628159564721
# The feature importance for token_name_ENG is : 1.8208979824378452e-05
# The feature importance for token_name_ETC is : 6.01930420946753e-05
# The feature importance for token_name_ETH is : 0.003617157884738681
# The feature importance for token_name_FIL is : 0.0
# The feature importance for token_name_G$ is : 5.532695250048194e-05
# The feature importance for token_name_GLM is : 0.0
# The feature importance for token_name_GLX is : 3.235100977207812e-07
# The feature importance for token_name_GNO is : 1.5870011399733732e-05
# The feature importance for token_name_HARBTY is : 2.383581657888968e-06
# The feature importance for token_name_HERC is : 0.00014731437360370587
# The feature importance for token_name_JAMM is : 0.0
# The feature importance for token_name_KEEP is : 2.5561455577111014e-05
# The feature importance for token_name_KIWI is : 0.0
# The feature importance for token_name_KNC is : 0.0
# The feature importance for token_name_KSM is : 3.451177150548953e-05
# The feature importance for token_name_LEAP is : 0.0
# The feature importance for token_name_LIKE is : 1.3672792281367566e-05
# The feature importance for token_name_LINK is : 1.7773470640271906e-06
# The feature importance for token_name_LPT is : 0.0001922694465431299
# The feature importance for token_name_LRC is : 0.0
# The feature importance for token_name_LUNA is : 2.89575797624009e-07
# The feature importance for token_name_MANA is : 0.00013382554403102993
# The feature importance for token_name_MATIC is : 0.0
# The feature importance for token_name_MESG is : 1.7506568354734618e-06
# The feature importance for token_name_MYB is : 1.5389721798636578e-05
# The feature importance for token_name_NKN is : 0.00023016134703356952
# The feature importance for token_name_NTV is : 0.0
# The feature importance for token_name_OCEAN is : 1.9715827670568983e-05
# The feature importance for token_name_ONE is : 1.5370031874930657e-05
# The feature importance for token_name_OTHER is : 6.895962213366921e-05
# The feature importance for token_name_PAN is : 1.3244496806490714e-05
# The feature importance for token_name_PBLC is : 0.0
# The feature importance for token_name_POLY is : 8.785875920955528e-06
# The feature importance for token_name_PROCN is : 6.369736002486106e-05
# The feature importance for token_name_RDN is : 0.00011150061619050033
# The feature importance for token_name_REN is : 0.0
# The feature importance for token_name_RHOC is : 0.0
# The feature importance for token_name_RLC is : 0.00022243691641845087
# The feature importance for token_name_RLY is : 1.3000337758518854e-05
# The feature importance for token_name_SAI is : 0.0019328365672158523
# The feature importance for token_name_SC is : 1.3152643628841808e-05
# The feature importance for token_name_SGR is : 0.0009138746074315321
# The feature importance for token_name_SHIP is : 0.0
# The feature importance for token_name_SNT is : 0.0001339629512869788
# The feature importance for token_name_SNX is : 4.465344512082841e-05
# The feature importance for token_name_ST is : 0.0
# The feature importance for token_name_STORJ is : 0.0007345284597777183
# The feature importance for token_name_SWAGG is : 0.0
# The feature importance for token_name_SYSX is : 0.000355882608667542
# The feature importance for token_name_TRB is : 0.00023734189357752837
# The feature importance for token_name_TUSD is : 5.2982294017618014e-05
# The feature importance for token_name_USD is : 0.0
# The feature importance for token_name_USDC is : 0.00044393054084649556
# The feature importance for token_name_USDT is : 0.0003063580955323046
# The feature importance for token_name_WBTC is : 3.8472353692007825e-06
# The feature importance for token_name_WYV is : 0.0
# The feature importance for token_name_XRT is : 4.503817871999351e-06
# The feature importance for token_name_ZIL is : 3.4603443055667235e-05
# The feature importance for token_name_ZRX is : 8.655796435199056e-05
# The feature importance for token_name_aDAI is : 0.00017628902801397704
# The feature importance for token_name_cUSD is : 1.04789020578406e-05
# The feature importance for token_name_wNXM is : 0.0
# The feature importance for project_type_contest is : 0.004176399883729329
# The feature importance for project_type_cooperative is : 0.003310782449212442
# The feature importance for project_type_traditional is : 0.004032837872422013
# The feature importance for firstAct_activity_type_NA is : 0.00024897631080505333
# The feature importance for firstAct_activity_type_bounty_changed is : 1.900406857585586e-05
# The feature importance for firstAct_activity_type_extend_expiration is : 0.0
# The feature importance for firstAct_activity_type_killed_bounty is : 3.7548001407364987e-06
# The feature importance for firstAct_activity_type_new_bounty is : 0.000852815883608063
# The feature importance for firstAct_activity_type_start_work is : 0.0006462704659520314
# The feature importance for firstAct_activity_type_unknown_event is : 0.0002629151833808929
# The feature importance for firstAct_activity_type_work_done is : 2.4921191358185e-05
# The feature importance for firstAct_activity_type_work_submitted is : 0.0004091045758623261
# The feature importance for firstAct_activity_type_worker_applied is : 0.0004767834946548704
# The feature importance for lastAct_activity_type_NA is : 0.00019409383099119353
# The feature importance for lastAct_activity_type_bounty_abandonment_escalation_to_mods is : 0.001188803445296603
# The feature importance for lastAct_activity_type_bounty_abandonment_warning is : 0.001027383607794633
# The feature importance for lastAct_activity_type_bounty_changed is : 0.0002671863874622607
# The feature importance for lastAct_activity_type_bounty_removed_by_staff is : 3.98818848609747e-05
# The feature importance for lastAct_activity_type_extend_expiration is : 0.0005829987112258551
# The feature importance for lastAct_activity_type_increased_bounty is : 0.00014397330627014907
# The feature importance for lastAct_activity_type_killed_bounty is : 0.03888318988599263
# The feature importance for lastAct_activity_type_new_bounty is : 0.0009902874471470662
# The feature importance for lastAct_activity_type_new_crowdfund is : 4.039404797980761e-06
# The feature importance for lastAct_activity_type_new_kudos is : 0.0007617682477643113
# The feature importance for lastAct_activity_type_new_tip is : 0.02316912009844536
# The feature importance for lastAct_activity_type_receive_kudos is : 0.0
# The feature importance for lastAct_activity_type_receive_tip is : 0.005228318670660083
# The feature importance for lastAct_activity_type_start_work is : 0.005029804234920738
# The feature importance for lastAct_activity_type_stop_work is : 0.012099239058221934
# The feature importance for lastAct_activity_type_unknown_event is : 0.0043454137150104
# The feature importance for lastAct_activity_type_work_done is : 0.041609022869593254
# The feature importance for lastAct_activity_type_work_submitted is : 0.008688883201158472
# The feature importance for lastAct_activity_type_worker_applied is : 0.0037082868441088244
# The feature importance for lastAct_activity_type_worker_approved is : 0.0001795834683568469
# The feature importance for lastAct_activity_type_worker_rejected is : 0.00010391817951479702
#                                  Feature  Feature Importance
# 12               duration_create_to_done            0.232071
# 9                 number_of_fulfillments            0.079457
# 15          duration_create_to_submitted            0.072079
# 16             duration_create_to_killed            0.052547
# 14            duration_create_to_lastAct            0.043540
# 8                   number_of_activities            0.042812
# 147      lastAct_activity_type_work_done            0.041609
# 137  lastAct_activity_type_killed_bounty            0.038883
# 10                   number_of_interests            0.036929
# 17         duration_create_to_new_bounty            0.029741
# 21          number_of_user_in_activities            0.023373
# 141        lastAct_activity_type_new_tip            0.023169
# 19               duration_create_to_stop            0.022338
# 3                          value_in_usdt            0.020822
# 13           duration_create_to_firstAct            0.020403
# 0              duration_create_to_expire            0.018595
# 11                    description_length            0.016740
# 18              duration_create_to_start            0.015476
# 4                      value_in_usdt_now            0.015464
# 1                           value_in_eth            0.015255
